# %% [markdown]
# # Support Vector Classifier

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('creditcard.csv')

# %%
# reducuing the columns to reduce the runtime
df = df[['V1', 'V2', 'V3', 'V4', 'Class']]

# %%
df.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'Class'], dtype='object')

# %%
df.Class.unique()
# Out:
# array([0, 1])

# %%
df.dtypes
# Out:
# V1       float64
# V2       float64
# V3       float64
# V4       float64
# Class      int64
# dtype: object

# %%
df.isna().sum()
# Out:
# V1       0
# V2       0
# V3       0
# V4       0
# Class    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(9144)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.Class.value_counts()
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %%
df_maj =df[df.Class == 0]
df_min =df[df.Class == 1]

# %%
from sklearn.utils import resample
df_maj = resample(df_maj, replace = False, n_samples = 10000, random_state=1)

# %%
df_maj.shape
# Out:
# (10000, 5)

# %%
from imblearn.over_sampling import SMOTE

# %%
ovs  = SMOTE()
X, y = ovs.fit_resample(df.drop('Class', axis = 1), df['Class'])

# %%
X.shape, y.shape
# Out:
# ((550380, 4), (550380,))

# %%
a = pd.concat([X, y], axis = 1)
a = a[a.Class == 1]
df_min = resample(a, replace = False, n_samples = 1000, random_state=1)

# %%
df_min.shape
# Out:
# (1000, 5)

# %%
df = pd.concat([df_maj.reset_index(drop=True), df_min.reset_index(drop=True)], axis=0)

# %%
df
# Out:
#             V1         V2         V3         V4  Class
# 0     1.304700  -0.468059   0.534593  -0.906835      0
# 1    -3.405931  -0.900032  -0.440663   0.062850      0
# 2     0.901430  -1.131116   0.454773  -0.399746      0
# 3    -1.502071  -1.221332   1.831980  -0.178694      0
# 4     0.289857  -2.744994   0.413814  -0.144797      0
# ..         ...        ...        ...        ...    ...
# 995  -5.387688   3.888409  -4.945670   4.171100      1
# 996  -0.475067   1.000261   0.631400   2.696644      1
# 997 -17.572802  10.199481 -24.290969  11.801789      1
# 998  -2.918635  -0.161221  -1.430591   3.494710      1
# 999  -2.359881   1.713487  -0.511136   3.133519      1
#
# [11000 rows x 5 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.shape
# Out:
# (11000, 5)

# %%
df.Class.value_counts()
# Out:
# Class
# 0    10000
# 1     1000
# Name: count, dtype: int64

# %% [markdown]
# Insight:
# - we can see here have dta imbalanced

# %%
# To handle class imbalanced data
# oversampling 
# undersampling
# SMOTE

# %%
X = df.drop('Class', axis=1)
y = df['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.30, random_state = 1)

# %%
X_train.shape
# Out:
# (7700, 4)

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC
clf = SVC(kernel = 'linear')
clf.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = clf.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      3025
#            1       0.93      0.68      0.78       275
#
#     accuracy                           0.97      3300
#    macro avg       0.95      0.84      0.88      3300
# weighted avg       0.97      0.97      0.97      3300
