# %% [markdown]
# # Support Vector Regressor

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
# reducuing the columns to reduce the runtime
# Amount is target variable
df = df[['V1', 'V2', 'V3', 'V4', 'Amount']]

# %%
# reducing no.of Rows
df = df.iloc[:20000]

# %%
df.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'Amount'], dtype='object')

# %%
df.dtypes
# Out:
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# Amount    float64
# dtype: object

# %%
df.isna().sum()
# Out:
# V1        0
# V2        0
# V3        0
# V4        0
# Amount    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(567)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
X = df.drop('Amount', axis=1)
y = df['Amount']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.30, random_state = 1)

# %%
X_train.shape
# Out:
# (13603, 4)

# %% [markdown]
# # SVR

# %%
from sklearn.svm import SVR
reg = SVR(kernel = 'linear')
reg.fit(X_train, y_train)
# Out:
# SVR(kernel='linear')

# %%
y_pred = reg.predict(X_test)
y_pred
# Out:
# array([31.32989668, 35.25249254,  1.93545996, ..., 25.98864229,
#        10.67724046, -0.25277634])

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test, y_pred))
# Out:
# 0.2898934700243515
